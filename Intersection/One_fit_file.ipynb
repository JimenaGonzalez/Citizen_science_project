# %%
import numpy as np
import pandas as pd
import os
import ipython_bell
import random
import codecs

from astropy.io import fits
from astropy.table import Table, Column
from tqdm.notebook import tqdm

# %%
data = pd.read_csv('data/in_sled2.csv')
data = data.astype({'COADD_OBJECT_ID': int, 'Y3_COADD_OBJECT_ID': int})
print(len(data))

data = data[data['score'].notnull()]
data['score'] = pd.to_numeric(data['score'], errors='coerce')
data = data.dropna(subset=['score'])
data = data.reset_index(drop=True)
data = data.astype({'score': float})
data = data.drop_duplicates(subset=['COADD_OBJECT_ID'])
print(len(data))
data.head()
# Out:
# 1687
# 1665
#          K_RA      K_DEC   K_SCORE  Y3_COADD_OBJECT_ID        J_RA      J_DEC  \
# 0    2.146579 -39.377357  0.001118           182434686    2.146579 -39.377357
# 1    1.117249 -38.735816  0.190351           142345819    1.117249 -38.735816
# 2    0.719928 -38.286190  0.999342           142322552    0.719928 -38.286190
# 3  359.354640 -39.374435  0.999394           213772612  359.354640 -39.374435
# 4  359.132439 -38.752750  0.000026           172759386  359.132439 -38.752750
#
#    score_sims  score_real  score_both  COADD_OBJECT_ID  ...  score  image_sep  \
# 0      0.0604         0.0         0.0       1046785880  ...    1.0       None
# 1      0.9792         0.0         0.0       1037197500  ...    1.0       None
# 2      0.2046         0.0         0.0       1037154929  ...    2.0       None
# 3      0.0104         0.0         0.0       1031999366  ...    1.0       None
# 4      0.9329         0.0         0.0       1028411116  ...    1.0       None
#
#    info  n_img       flag  image_conf  lens_type  source_type  \
# 0   NaN   None  CANDIDATE         NaN     Galaxy          NaN
# 1   NaN   None  CANDIDATE         NaN     Galaxy          NaN
# 2   NaN   None  CANDIDATE         NaN     Galaxy          NaN
# 3   NaN   None  CANDIDATE         NaN     Galaxy          NaN
# 4   NaN   None  CANDIDATE         NaN     Galaxy          NaN
#
#    contaminant_type                                    papers
# 0               NaN                       2019ApJS..243...17J
# 1               NaN                       2019ApJS..243...17J
# 2               NaN                       2022A&A...668A..73R
# 3               NaN                       2019ApJS..243...17J
# 4               NaN  2019ApJS..243...17J, 2022arXiv220602764S
#
# [5 rows x 35 columns]

# %%
x = np.zeros((1,3,75,75))
path_cut = 'data/Fit_files/'
end_name = ['_g.fits', '_i.fits', '_r.fits']
list_coadd_ids = []

for file in tqdm(os.listdir(path_cut)):
    if(file[0:3] != 'DES'): continue
    path2 = path_cut + file + '/'
    for file2 in (os.listdir(path2)):
        coadd_id_tmp = file2
        for file3 in (os.listdir(path2 + file2)):
            if(file3[-6:] == 'g.fits'):
                path3 = path2 + file2 + '/'+ file3[:-7]
                with fits.open(path3 + end_name[0]) as hdul: cutout_g = hdul[0].data
                with fits.open(path3 + end_name[1]) as hdul: cutout_i = hdul[0].data
                with fits.open(path3 + end_name[2]) as hdul: cutout_r = hdul[0].data
                
                element = np.array([cutout_g, cutout_r, cutout_i])
                x = np.append(x, [element], axis = 0)
                list_coadd_ids.append(int(coadd_id_tmp))
                
x = np.delete(x, 0, axis = 0)
# Out:
#   0%|          | 0/1437 [00:00<?, ?it/s]

# %%
new_data = pd.DataFrame()
new_data['COADD_OBJECT_ID'] = list_coadd_ids

data.set_index('COADD_OBJECT_ID', inplace=True)
new_data.set_index('COADD_OBJECT_ID', inplace=True)
data = data.reindex(new_data.index)
# Reset index if you want to return COADD_OBJECT_ID to a column
data.reset_index(inplace=True)

print(x.shape, len(data))
data.head()
# Out:
# (1672, 3, 75, 75) 1672
#    COADD_OBJECT_ID       K_RA      K_DEC   K_SCORE  Y3_COADD_OBJECT_ID  \
# 0       1538255919  78.309585 -52.505695  0.944468         413391817.0
# 1       1537731200  77.456831 -52.455477  0.411994         413390304.0
# 2       1510424134  72.587800 -50.743626  0.000009         483404421.0
# 3       1044445712   2.526065   3.911200  0.000008         178846367.0
# 4       1478069288  66.905377 -22.080270  0.996424         498287987.0
#
#         J_RA      J_DEC  score_sims  score_real  score_both  ...  score  \
# 0  78.309585 -52.505695      0.0000         0.0         0.0  ...   2.00
# 1  77.456831 -52.455477      0.0000         0.0         0.0  ...   1.80
# 2  72.587800 -50.743626      0.0000         0.0         0.0  ...   1.33
# 3   2.526065   3.911200      0.1880         0.0         0.0  ...   2.00
# 4  66.905377 -22.080270      0.9188         0.0         0.0  ...   1.00
#
#    image_sep  info  n_img       flag  image_conf  lens_type  source_type  \
# 0       None   NaN   None  CANDIDATE         NaN     Galaxy          NaN
# 1       7.72   NaN   None  CANDIDATE         NaN     Galaxy          NaN
# 2       None   NaN   None  CANDIDATE         NaN     Galaxy          NaN
# 3       None   NaN   None  CANDIDATE         NaN     Galaxy          NaN
# 4       None   NaN   None  CANDIDATE         NaN     Galaxy          NaN
#
#    contaminant_type                                    papers
# 0               NaN  2022A&A...668A..73R, 2022arXiv220602764S
# 1               NaN                       2017ApJS..232...15D
# 2               NaN  2019ApJS..243...17J, 2019MNRAS.484.5330J
# 3               NaN                       2022ApJ...932..107S
# 4               NaN  2022A&A...668A..73R, 2022arXiv220602764S
#
# [5 rows x 35 columns]

# %%
# Ensure all object dtype columns are strings and encode them to bytes
for col in data.select_dtypes(include=['object']).columns:
    data[col] = data[col].apply(lambda x: x.encode('utf-8') if isinstance(x, str) else x)

# Convert the pandas DataFrame to an Astropy Table
columns = []
for colname in data.columns:
    if data[colname].dtype == 'object':
        col = Column(name=colname, data=data[colname], dtype='S')
    else:
        col = Column(name=colname, data=data[colname])
    columns.append(col)

# %%
#table_data = Table.from_pandas(data)
table_data = Table(columns)

name = 'in_sled2'
primary = fits.PrimaryHDU()
image = fits.ImageHDU(x, name="IMAGE")
#table = fits.BinTableHDU(data = table_data)
#table = fits.BinTableHDU(table_data.as_array(), character_as_bytes=False)
table = fits.BinTableHDU(table_data)
hdu_list = fits.HDUList([primary, image, table])
hdu_list.writeto('data/' + name + '.fits', overwrite=True)
